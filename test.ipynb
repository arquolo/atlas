# %%
import gigaslide as gs

# %%
help(gs)
# Out:
# Help on module gigaslide:
#
# NAME
#     gigaslide
#
# CLASSES
#     pybind11_builtins.pybind11_object(builtins.object)
#         Color
#         Codec
#         Data
#         ImageBase
#         Interpolation
#
#     class Color(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Color
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(...)
#      |      __eq__(self: gigaslide.Color, arg0: gigaslide.Color) -> bool
#      |
#      |  __getstate__(...)
#      |      __getstate__(self: gigaslide.Color) -> tuple
#      |
#      |  __hash__(...)
#      |      __hash__(self: gigaslide.Color) -> int
#      |
#      |  __init__(...)
#      |      __init__(self: gigaslide.Color, arg0: int) -> None
#      |
#      |  __int__(...)
#      |      __int__(self: gigaslide.Color) -> int
#      |
#      |  __ne__(...)
# ...
